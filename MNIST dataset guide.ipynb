# %% [markdown]
# You can download mnist with this code (in command prompt), but I already downloaded in put it in the file:
#
# > curl -O http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio
import scipy as sio
import os
import pandas as pd
from scipy import ndimage

# %%
#%%
from mlxtend.data import loadlocal_mnist
import platform

if not platform.system()=='Windows':
    X_data, Y_label=loadlocal_mnist(
    images_path='MNIST/train-images-idx3-ubyte',
    labels_path="MNIST/train-labels-idx1-ubyte")
else:
    X_data, Y_label=loadlocal_mnist(
    images_path='MNIST/train-images.idx3-ubyte',
    labels_path="MNIST/train-labels.idx1-ubyte")

# %%
#%%
# %matplotlib inline
print('Dimensions: %s x %s' % (X_data.shape[0], X_data.shape[1]))
print('\n1st row', X_data[0])
#%%
#Reshape data
X_data= X_data.reshape(60000,28,28)
X_data= X_data.astype('float32')
X_data /= 255 
print("Training X matrix shape", X_data.shape)
print("Label vector shape", Y_label.shape)
# Out:
# Dimensions: 60000 x 28
#
# 1st row [[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
# ...
